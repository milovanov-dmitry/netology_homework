# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://public.mai.ru/priem/rating/data/p20200814135902_1_l1_s53_f1_p1.html'


res = requests.get(url)
res.encoding = 'utf-8'

# %%
soup = BeautifulSoup(res.text, 'html.parser')
texts = soup.find_all('td')

# %%
for text in texts:
    print(text.string)
# Out:
# 1
# БД-03-13346
# Валеева Ильнара Ирфановна
# 254
# 76
# 84
# 94
#  0
#
#
# 2
# БД-03-17867
# Бибиков Павел Алексеевич
# 240
# 84
# 83
# 73
#  0
#
# ✓
# 3
# БД-06-19095
# Кондрашин Евгений Андреевич
# 232
# 62
# 81
# 89
#  0
#
# ✓
# 4
# БД-03-3468
# Небренчин Даниил Сергеевич
# 225
# 68
# 75
# 82
#  0
#
#
# 5
# БД-01-13667
# Филимонов Роман Георгиевич
# 187
# 56
# 59
# 72
#  0
#
#
# None
# БД-01-10352
# Провоторов Алексей Дмитриевич
# 229
# 78
# 64
# 87
#  0
# ✓
#
#
# 2
# БД-02-16782
# Комаров Никита Михайлович
# 229
# 72
# 72
# 85
#  0
#
# ✓
#
# 3
# БД-01-6931
# Анохин Михаил Алексеевич
# 224
# 72
# 77
# 70
# 5
#
#
#
# None
# БД-01-18161
# Завтрик Семён Александрович
# 205
# 50
# 73
# 82
#  0
# ✓
# ✓
#
# 5
# БД-04-18283
# Кривенко Анастасия Витальевна
# 204
# 56
# 75
# 73
#  0
#
# ✓
#
# 6
# БД-03-18414
# Донодин Максим Анатольевич
# 199
# 56
# 61
# 82
#  0
#
# ✓
#
# None
# БД-01-9629
# Папетин Фёдор Александрович
# 197
# 68
# 57
# 72
#  0
# ✓
#
#
# 1
# БД-04-1870
# ...

# %%
print(content)
